# %%
import matplotlib.pyplot as plt
import os
import astropy
import numpy as np
import scipy
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
os.environ['WEBBPSF_PATH'] = 'C:\\temp\\webbpsf-data' #This line changes the environment variable to tell Python where to locate WebbPSF

# %%
pip install --upgrade webbpsf
# Out:
# ...
#
# ...

# %%
pip install synphot
# Out:
# ...
#
# ...

# %%
import webbpsf

# %%
import numpy as np
import astropy
import math
import pandas as pd
import matplotlib.pyplot as plt
import scipy
import matplotlib
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
from scipy.stats import norm
from scipy.ndimage import shift
from scipy.optimize import curve_fit

# %%
#This code taken directly from https://webbpsf.readthedocs.io/en/latest/usage.html with minor modifications.
nc = webbpsf.NIRCam()
nc.filter =  'F356W'
psf = nc.calc_psf(fov_pixels = 200, oversample=1)     
plt.imshow(psf[0].data)             
webbpsf.display_psf(psf)  
psf.writeto("356W_Analytical_b.fits")
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]

# %%
#This code taken directly from https://webbpsf.readthedocs.io/en/latest/usage.html with minor modifications.
miri = webbpsf.MIRI()
miri.filter =  'F1800W'
psf = miri.calc_psf(fov_pixels = 200, oversample=1)     
plt.imshow(psf[0].data)             
webbpsf.display_psf(psf)    
psf.writeto("1800W_Analytical.fits")
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
